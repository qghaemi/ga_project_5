# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./Datasets/cleaned_df.csv', index_col='date')

# %%
df.index = pd.to_datetime(df.index)

# %%
df.head(369)
# Out:
#             state_name county_name  county_code  aqi  \
# date
# 2013-01-01  California     Alameda            1   62
# 2013-01-02  California     Alameda            1   61
# 2013-01-03  California     Alameda            1   81
# 2013-01-04  California     Alameda            1   78
# 2013-01-05  California     Alameda            1   84
# ...                ...         ...          ...  ...
# 2013-12-31  California     Alameda            1  101
# 2013-03-29  California      Alpine            3   21
# 2013-04-10  California      Alpine            3   21
# 2013-04-22  California      Alpine            3   18
# 2013-05-23  California      Alpine            3   14
#
#                                   category defining_parameter defining_site  \
# date
# 2013-01-01                        Moderate              PM2.5   06-001-0007
# 2013-01-02                        Moderate              PM2.5   06-001-0007
# 2013-01-03                        Moderate              PM2.5   06-001-0007
# 2013-01-04                        Moderate              PM2.5   06-001-0007
# 2013-01-05                        Moderate              PM2.5   06-001-0007
# ...                                    ...                ...           ...
# 2013-12-31  Unhealthy for Sensitive Groups              PM2.5   06-001-0007
# 2013-03-29                            Good              PM2.5   06-003-1001
# 2013-04-10                            Good              PM2.5   06-003-1001
# 2013-04-22                            Good              PM2.5   06-003-1001
# 2013-05-23                            Good              PM2.5   06-003-1001
#
#             number_of_sites_reporting
# date
# 2013-01-01                          4
# 2013-01-02                          4
# 2013-01-03                          4
# 2013-01-04                          4
# 2013-01-05                          4
# ...                               ...
# 2013-12-31                          3
# 2013-03-29                          1
# 2013-04-10                          1
# 2013-04-22                          1
# 2013-05-23                          1
#
# [369 rows x 8 columns]

# %%
len(df['county_code'].unique())
# Out:
# 54

# %%
aqi_county = df.groupby('county_name').mean()
aqi_county.sort_values('aqi', ascending=False).head(20)
# Out:
#                 county_code        aqi  number_of_sites_reporting
# county_name
# San Bernardino         71.0  96.003051                  13.321051
# Riverside              65.0  95.258214                  15.007635
# Kern                   29.0  89.184826                   9.743559
# Los Angeles            37.0  88.113571                  15.768333
# Tulare                107.0  85.825862                   3.845341
# Fresno                 19.0  83.543929                   7.980424
# Kings                  31.0  75.237159                   2.630264
# Inyo                   27.0  69.379166                  13.240270
# San Diego              73.0  69.166903                  10.575414
# Mono                   51.0  67.701119                   2.654680
# Stanislaus             99.0  66.445351                   1.980890
# Madera                 39.0  65.597446                   2.055582
# Imperial               25.0  65.455387                   4.581395
# Merced                 47.0  62.153702                   1.291287
# Sacramento             67.0  61.913023                   7.861262
# Placer                 61.0  59.616053                   4.155597
# San Joaquin            77.0  59.321370                   2.855512
# Orange                 59.0  58.944762                   4.239048
# Mariposa               43.0  58.911758                   2.617226
# Butte                   7.0  58.419286                   3.693926

# %%
plt.hist(aqi_county['aqi'], bins=54); #bins equal to exact count of counties

# %%
def_param = df.groupby('defining_parameter').mean()
def_param = def_param.reset_index()

# %%
def_param
# Out:
#   defining_parameter  county_code        aqi  number_of_sites_reporting
# 0                 CO    51.507463  25.164179                   3.626866
# 1                NO2    57.858324  41.573319                   5.176957
# 2              Ozone    58.499788  53.886557                   4.279999
# 3               PM10    47.809114  73.795398                   5.031399
# 4              PM2.5    58.042919  56.720513                   4.194530
# 5                SO2    52.862069  66.586207                   9.068966

# %%
plt.bar(x=def_param['defining_parameter'], height=def_param['aqi'])
plt.grid(False)
plt.ylabel('AQI');

# %%
df.sort_index(ascending=True)
# Out:
#             state_name county_name  county_code  aqi  \
# date
# 2009-01-01  California      Fresno           19  104
# 2009-01-01  California   Mendocino           45   20
# 2009-01-01  California        Mono           51   56
# 2009-01-01  California        Inyo           27   53
# 2009-01-01  California      Orange           59  156
# ...                ...         ...          ...  ...
# 2020-10-30  California   Riverside           65   40
# 2020-10-31  California      Plumas           63   69
# 2020-10-31  California       Kings           31  103
# 2020-10-31  California      Nevada           57   49
# 2020-10-31  California   Riverside           65   45
#
#                                   category defining_parameter defining_site  \
# date
# 2009-01-01  Unhealthy for Sensitive Groups              PM2.5   06-019-0008
# 2009-01-01                            Good              Ozone   06-045-0008
# 2009-01-01                        Moderate               PM10   06-051-0001
# 2009-01-01                        Moderate               PM10   06-027-1003
# 2009-01-01                       Unhealthy              PM2.5   06-059-0007
# ...                                    ...                ...           ...
# 2020-10-30                            Good               PM10   06-065-0500
# 2020-10-31                        Moderate              PM2.5   06-063-1006
# 2020-10-31  Unhealthy for Sensitive Groups               PM10   06-031-0500
# 2020-10-31                            Good              PM2.5   06-057-0005
# 2020-10-31                            Good               PM10   06-065-0500
#
#             number_of_sites_reporting
# date
# 2009-01-01                          7
# 2009-01-01                          1
# 2009-01-01                          3
# 2009-01-01                         14
# 2009-01-01                          4
# ...                               ...
# 2020-10-30                          2
# 2020-10-31                          3
# 2020-10-31                          1
# 2020-10-31                          2
# 2020-10-31                          2
#
# [218538 rows x 8 columns]

# %%
df.index = pd.to_datetime(df.index)

# %%
df_daily = df.resample('D').mean()

# %%
def auto_corr(lag):
    ac = df_daily['aqi'].autocorr(lag=lag)
    print(f'Autocorellation for {lag} day(s) is: {ac}')

# %%
print(auto_corr(1), auto_corr(2), auto_corr(7), auto_corr(30), auto_corr(365))
# Out:
# Autocorellation for 1 day(s) is: 0.6405783382599282
# Autocorellation for 2 day(s) is: 0.47254052609570435
# Autocorellation for 7 day(s) is: 0.27212753344972235
# Autocorellation for 30 day(s) is: 0.14650526083550477
# Autocorellation for 365 day(s) is: 0.16687468620962348
# None None None None None

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
fig, ax = plt.subplots(figsize=(16,9))
plot_acf(df_daily['aqi'], ax=ax);

# %%
fig, ax = plt.subplots(figsize=(16,9))
plot_pacf(df_daily['aqi'], ax=ax);
